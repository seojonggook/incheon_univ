# %% [markdown]
# ## 한글 폰트 설치

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %% [markdown]
# # Facebook Prophet을 활용한 시계열 데이터 예측 모델

# %% [markdown]
# 이번 튜토리얼 에서는 다음과 같은 **프로세스 파이프라인**으로 주가 예측을 진행합니다.
#
# - FinanceDataReader를 활용하여 주가 데이터 받아오기
# - Facebook Prophet을 활용하여 주가 예측

# %% [markdown]
# ## 필요한 모듈 import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os

# %matplotlib inline
warnings.filterwarnings('ignore')

plt.rc('font', family='NanumBarunGothic')

# %% [markdown]
# ## 데이터 (FinanceDataReader)

# %% [markdown]
# **FinanceDataReader**는 주가 데이터를 편리하게 가져올 수 있는 파이썬 패키지입니다.
#
# - [GitHub Repo](https://github.com/FinanceData/FinanceDataReader)

# %% [markdown]
# **FinanceDataReader**가 아직 설치 되지 않으신 분들은 아래의 주석을 해제한 후 명령어로 설치해 주시기 바랍니다.

# %%
# !pip install finance-datareader
# Out:
# Requirement already satisfied: finance-datareader in /usr/local/lib/python3.7/dist-packages (0.9.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from finance-datareader) (4.62.3)
# Requirement already satisfied: requests-file in /usr/local/lib/python3.7/dist-packages (from finance-datareader) (1.5.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from finance-datareader) (4.2.6)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.7/dist-packages (from finance-datareader) (1.1.5)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from finance-datareader) (2.23.0)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19.2->finance-datareader) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19.2->finance-datareader) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19.2->finance-datareader) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.3.0->finance-datareader) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.3.0->finance-datareader) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.3.0->finance-datareader) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.3.0->finance-datareader) (2021.10.8)

# %%
import FinanceDataReader as fdr

# %%
# 삼성전자 종목코드: 005930
samsung = fdr.DataReader('005930')

# %% [markdown]
# 매우 편리하게 삼성전자 주가 데이터를 `DataFrame`형식으로 받아옵니다.
#
# 기본 **오름차순 정렬**이 된 데이터임을 알 수 있습니다.
#
# ### 컬럼 설명
#
# - `Open`:   시가
# - `High`:   고가
# - `Low`:    저가
# - `Close`:  종가
# - `Volume`: 거래량
# - `Change`: 대비

# %%
samsung.tail()
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2021-12-06  75100  76700  74900  76300  16391250  0.009259
# 2021-12-07  76100  77700  75600  77400  19232453  0.014417
# 2021-12-08  78300  78600  77100  77400  21558340  0.000000
# 2021-12-09  77400  78200  77000  78200  21604528  0.010336
# 2021-12-10  77400  77600  76800  76900   9091202 -0.016624

# %% [markdown]
# **미국 주식 데이터**도 가져올 수 있습니다.

# %%
# Apple(AAPL), 애플
apple = fdr.DataReader('AAPL')

# %%
apple.tail()
# Out:
#              Close    Open    High     Low       Volume  Change
# Date
# 2021-12-06  165.32  164.29  167.88  164.28  106620000.0  0.0215
# 2021-12-07  171.18  169.08  171.58  168.34  115600000.0  0.0354
# 2021-12-08  175.08  172.13  175.96  170.70  116390000.0  0.0228
# 2021-12-09  174.56  174.91  176.75  173.92  108510000.0 -0.0030
# 2021-12-10  179.45  175.21  179.63  174.69  115400000.0  0.0280

# %% [markdown]
# ### 비트코인 시세

# %%
btc = fdr.DataReader('BTC/KRW', '2018-01-01')
btc
# Out:
#                Close      Open      High       Low   Volume  Change
# Date
# 2018-01-01  18655000  19208000  19296000  18362000  10240.0 -0.0288
# 2018-01-02  19838000  18655000  20800000  18570000  17460.0  0.0634
# 2018-01-03  20419000  19838000  20810000  19800000  15670.0  0.0293
# 2018-01-04  21576000  20419000  21830000  19891000  14730.0  0.0567
# 2018-01-05  25026000  21576000  25988000  21046000  25290.0  0.1599
# ...              ...       ...       ...       ...      ...     ...
# 2021-12-08  62063000  63063000  63299000  60500000    420.0 -0.0159
# 2021-12-09  59307000  62073000  62350000  59050000    800.0 -0.0444
# 2021-12-10  59705000  59191000  61901000  58990000    730.0  0.0067
# 2021-12-11  61410000  59663000  61490000  59500000    490.0  0.0286
# 2021-12-12  61838000  61412000  62130000  60864000     30.0  0.0070
#
# [1440 rows x 6 columns]

# %% [markdown]
# ## 시세에 대한 그래프 시각화

# %%
plt.figure(figsize=(16, 9))
sns.lineplot(x=btc.index, y='Close', data=btc)
plt.show()

# %% [markdown]
# **시작**과 **끝** 날짜를 지정하여 범위 데이터를 가져올 수 있습니다.

# %%
# 비트코인 시세
btc = fdr.DataReader('BTC/KRW', '2019-01-01', '2020-12-01')
btc
# Out:
#                Close      Open      High       Low   Volume  Change
# Date
# 2019-01-01   4289000   4199000   4300000   4137000   3230.0  0.0214
# 2019-01-02   4345000   4294000   4360000   4244000   3860.0  0.0131
# 2019-01-03   4282000   4352000   4367000   4259000  15370.0 -0.0145
# 2019-01-04   4309000   4286000   4334000   4243000  19200.0  0.0063
# 2019-01-05   4297000   4309000   4354000   4278000  24870.0 -0.0028
# ...              ...       ...       ...       ...      ...     ...
# 2020-11-27  19119000  19236000  19236000  19119000   1440.0 -0.0067
# 2020-11-28  19480000  19118000  19480000  19118000   1610.0  0.0189
# 2020-11-29  20002000  19480000  20002000  19281000    830.0  0.0268
# 2020-11-30  21302000  19996000  21302000  19996000   2520.0  0.0650
# 2020-12-01  20848000  21302000  21302000  20848000   1830.0 -0.0213
#
# [699 rows x 6 columns]

# %%
plt.figure(figsize=(16, 9))
sns.lineplot(x=btc.index, y='Close', data=btc)
plt.show()

# %% [markdown]
# 그 밖에 **금, 은과 같은 현물**, **달러와 같은 화폐** 데이터도 가져올 수 있습니다.

# %% [markdown]
# 더욱 자세한 내용은 [GitHub 페이지 링크](https://github.com/FinanceData/FinanceDataReader)를 참고해 보시기 바랍니다.

# %% [markdown]
# ## 주가데이터 가져오기

# %%
# 삼성전자 주식코드: 005930
STOCK_CODE = '005930'

# %%
stock = fdr.DataReader(STOCK_CODE)

# %%
stock.head()
# Out:
#             Open  High  Low  Close  Volume    Change
# Date
# 1997-11-08   761   809  761    810  320624       NaN
# 1997-11-10   809   872  809    870  376400  0.074074
# 1997-11-11   857   888  823    836  314560 -0.039080
# 1997-11-12   831   831  791    804  304710 -0.038278
# 1997-11-13   822   836  798    799  273800 -0.006219

# %%
stock.index
# Out:
# DatetimeIndex(['1997-11-08', '1997-11-10', '1997-11-11', '1997-11-12',
#                '1997-11-13', '1997-11-14', '1997-11-15', '1997-11-17',
#                '1997-11-18', '1997-11-19',
#                ...
#                '2021-11-29', '2021-11-30', '2021-12-01', '2021-12-02',
#                '2021-12-03', '2021-12-06', '2021-12-07', '2021-12-08',
#                '2021-12-09', '2021-12-10'],
#               dtype='datetime64[ns]', name='Date', length=6000, freq=None)

# %%
stock.head()
# Out:
#             Open  High  Low  Close  Volume    Change
# Date
# 1997-11-08   761   809  761    810  320624       NaN
# 1997-11-10   809   872  809    870  376400  0.074074
# 1997-11-11   857   888  823    836  314560 -0.039080
# 1997-11-12   831   831  791    804  304710 -0.038278
# 1997-11-13   822   836  798    799  273800 -0.006219

# %% [markdown]
# ## 시각화

# %%
plt.figure(figsize=(16, 9))
sns.lineplot(y=stock['Close'], x=stock.index)
plt.xlabel('time')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
time_steps = [['1990', '2000'], 
              ['2000', '2010'], 
              ['2010', '2015'], 
              ['2015', '2020']]

fig, axes = plt.subplots(2, 2)
fig.set_size_inches(16, 9)
for i in range(4):
    ax = axes[i//2, i%2]
    df = stock.loc[(stock.index > time_steps[i][0]) & (stock.index < time_steps[i][1])]
    sns.lineplot(y=df['Close'], x=df.index, ax=ax)
    ax.set_title(f'{time_steps[i][0]}~{time_steps[i][1]}')
    ax.set_xlabel('time')
    ax.set_ylabel('price')
plt.tight_layout()
plt.show()

# %%
stock = fdr.DataReader(STOCK_CODE, '2019')

# %% [markdown]
# ## Prophet

# %% [markdown]
# ### 모듈 import

# %%
from fbprophet import Prophet
from fbprophet.plot import plot_plotly, plot_components_plotly

# %% [markdown]
# ### 컬럼

# %% [markdown]
# - 반드시 **y** 컬럼과 **ds** 컬럼이 존재해야합니다.
# - 예측 값은 **y**, 시계열 데이터는 **ds**에 지정합니다.

# %%
stock['y'] = stock['Close']
stock['ds'] = stock.index

# %%
stock.head()
# Out:
#              Open   High    Low  Close    Volume    Change      y         ds
# Date
# 2019-01-02  39400  39400  38550  38750   7847664  0.001292  38750 2019-01-02
# 2019-01-03  38300  38550  37450  37600  12471493 -0.029677  37600 2019-01-03
# 2019-01-04  37450  37600  36850  37450  14108958 -0.003989  37450 2019-01-04
# 2019-01-07  38000  38900  37800  38750  12748997  0.034713  38750 2019-01-07
# 2019-01-08  38000  39200  37950  38100  12756554 -0.016774  38100 2019-01-08

# %% [markdown]
# ### prophet 객체 선언 및 학습

# %%
m = Prophet()
m.fit(stock)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# **period**에 예측 하고 싶은 기간을 입력 합니다.
#
# 예측할 시계열 row가 추가 됩니다.

# %% [markdown]
# `periods`에 예측할 기간을 입력합니다.

# %%
future = m.make_future_dataframe(periods=30)
future.tail()
# Out:
#             ds
# 753 2022-01-05
# 754 2022-01-06
# 755 2022-01-07
# 756 2022-01-08
# 757 2022-01-09

# %% [markdown]
# - `predict`로 예측을 진행합니다.
# - `predict` 안에는 이전 단계에서 만들어준 future 데이터프레임을 입력합니다.

# %%
forecast = m.predict(future)
forecast.tail()
# Out:
#             ds         trend  ...  multiplicative_terms_upper          yhat
# 753 2022-01-05  76748.332495  ...                         0.0  82945.799254
# 754 2022-01-06  76716.996407  ...                         0.0  83224.333530
# 755 2022-01-07  76685.660319  ...                         0.0  83508.324143
# 756 2022-01-08  76654.324231  ...                         0.0  88350.978041
# 757 2022-01-09  76622.988143  ...                         0.0  88628.089214
#
# [5 rows x 19 columns]

# %%
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']
00:00:00", "2019-05-21T00:00:00", "2019-05-22T00:00:00", "2019-05-23T00:00:00", "2019-05-24T00:00:00", "2019-05-27T00:00:00", "2019-05-28T00:00:00", "2019-05-29T00:00:00", "2019-05-30T00:00:00", "2019-05-31T00:00:00", "2019-06-03T00:00:00", "2019-06-04T00:00:00", "2019-06-05T00:00:00", "2019-06-07T00:00:00", "2019-06-10T00:00:00", "2019-06-11T00:00:00", "2019-06-12T00:00:00", "2019-06-13T00:00:00", "2019-06-14T00:00:00", "2019-06-17T00:00:00", "2019-06-18T00:00:00", "2019-06-19T00:00:00", "2019-06-20T00:00:00", "2019-06-21T00:00:00", "2019-06-24T00:00:00", "2019-06-25T00:00:00", "2019-06-26T00:00:00", "2019-06-27T00:00:00", "2019-06-28T00:00:00", "2019-07-01T00:00:00", "2019-07-02T00:00:00", "2019-07-03T00:00:00", "2019-07-04T00:00:00", "2019-07-05T00:00:00", "2019-07-08T00:00:00", "2019-07-09T00:00:00", "2019-07-10T00:00:00", "2019-07-11T00:00:00", "2019-07-12T00:00:00", "2019-07-15T00:00:00", "2019-07-16T00:00:00", "2019-07-17T00:00:00", "2019-07-18T00:00:00", "2019-07-19T00:00:00", "2019-07-22T00:00:00", "2019-07-23T00:00:00", "2019-07-24T00:00:00", "2019-07-25T00:00:00", "2019-07-26T00:00:00", "2019-07-29T00:00:00", "2019-07-30T00:00:00", "2019-07-31T00:00:00", "2019-08-01T00:00:00", "2019-08-02T00:00:00", "2019-08-05T00:00:00", "2019-08-06T00:00:00", "2019-08-07T00:00:00", "2019-08-08T00:00:00", "2019-08-09T00:00:00", "2019-08-12T00:00:00", "2019-08-13T00:00:00", "2019-08-14T00:00:00", "2019-08-16T00:00:00", "2019-08-19T00:00:00", "2019-08-20T00:00:00", "2019-08-21T00:00:00", "2019-08-22T00:00:00", "2019-08-23T00:00:00", "2019-08-26T00:00:00", "2019-08-27T00:00:00", "2019-08-28T00:00:00", "2019-08-29T00:00:00", "2019-08-30T00:00:00", "2019-09-02T00:00:00", "2019-09-03T00:00:00", "2019-09-04T00:00:00", "2019-09- ...

# %% [markdown]
# ### change points

# %% [markdown]
# By default, Prophet specifies 25 potential changepoints which are uniformly placed in the first 80% of the time series. The vertical lines in this figure indicate where the potential changepoints were placed:

# %% [markdown]
# 처음 80%의 시계열 데이터에 대하여 잠재적인 25개의 changepoints를 만들고, 그 중 선별하여 최종 changepoints를 그래프에서 vertical line으로 그려주게 됩니다.

# %%
from fbprophet.plot import add_changepoints_to_plot

# %%
fig = m.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), m, forecast)

# %% [markdown]
# ### flexibility 조절

# %% [markdown]
# If the trend changes are being overfit (too much flexibility) or underfit (not enough flexibility), you can adjust the strength of the sparse prior using the input argument changepoint_prior_scale. By default, this parameter is set to 0.05. Increasing it will make the trend more flexible:

# %% [markdown]
# flexibility **계수가 낮으면 과소적합, 높으면 과대적합**하여 예측하게 됩니다.
#
# 중요한 hyperparameter 입니다.

# %%
m = Prophet(changepoint_prior_scale=0.8)
forecast = m.fit(stock).predict(future)
fig = m.plot(forecast)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
m = Prophet(changepoint_prior_scale=0.01)
forecast = m.fit(stock).predict(future)
fig = m.plot(forecast)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# ## 서울시 코로나 확진자 현황

# %% [markdown]
# [데이터셋 다운로드](http://data.seoul.go.kr/dataList/OA-20279/S/1/datasetView.do)

# %%
# 서울시 코로나 확진자 데이터 다운로드
# !wget -O seoul_covid.csv https://www.dropbox.com/s/vv9mh6ciq9xnart/seoul_covid19.csv?dl=1
# Out:
# --2021-12-12 16:45:09--  https://www.dropbox.com/s/vv9mh6ciq9xnart/seoul_covid19.csv?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.18, 2620:100:6016:18::a27d:112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/vv9mh6ciq9xnart/seoul_covid19.csv [following]
# --2021-12-12 16:45:09--  https://www.dropbox.com/s/dl/vv9mh6ciq9xnart/seoul_covid19.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc2eed7a39944792a94aa9dcdabf.dl.dropboxusercontent.com/cd/0/get/BbsQjyAc5wPCQGvBAq0FXFMJShvfOyVWfYzl5Wpkd_0tOaGMJ7jXAa985UegUQMBFQ5BSnuPslyErz18F6p3TCPdgm0hCxBj-FxpxIPDHDdLX9SYA_fnntopQ-bodp5bi2c9PK5VaLFqp2F5vRmTCrar/file?dl=1# [following]
# --2021-12-12 16:45:10--  https://uc2eed7a39944792a94aa9dcdabf.dl.dropboxusercontent.com/cd/0/get/BbsQjyAc5wPCQGvBAq0FXFMJShvfOyVWfYzl5Wpkd_0tOaGMJ7jXAa985UegUQMBFQ5BSnuPslyErz18F6p3TCPdgm0hCxBj-FxpxIPDHDdLX9SYA_fnntopQ-bodp5bi2c9PK5VaLFqp2F5vRmTCrar/file?dl=1
# Resolving uc2eed7a39944792a94aa9dcdabf.dl.dropboxusercontent.com (uc2eed7a39944792a94aa9dcdabf.dl.dropboxusercontent.com)... 162.125.1.15, 2620:100:6022:15::a27d:420f
# Connecting to uc2eed7a39944792a94aa9dcdabf.dl.dropboxusercontent.com (uc2eed7a39944792a94aa9dcdabf.dl.dropboxusercontent.com)|162.125.1.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20797994 (20M) [application/binary]
# Saving to: ‘seoul_covid.csv’
#
# seoul_covid.csv     100%[===================>]  19.83M  44.7MB/s    in 0.4s
#
# 2021-12-12 16:45:10 (44.7 MB/s) - ‘seoul_covid.csv’ saved [20797994/20797994]

# %%
corona = pd.read_csv('seoul_covid.csv')
corona
# Out:
#             연번         확진일  환자번호  ...               등록일               수정일 노출여부
# 0       182558  2021-12-11   NaN  ...  2021-12-12 10:48  2021-12-12 10:48    Y
# 1       182557  2021-12-11   NaN  ...  2021-12-12 10:48  2021-12-12 10:48    Y
# 2       182556  2021-12-11   NaN  ...  2021-12-12 10:48  2021-12-12 10:48    Y
# 3       182555  2021-12-11   NaN  ...  2021-12-12 10:48  2021-12-12 10:48    Y
# 4       182554  2021-12-11   NaN  ...  2021-12-12 10:48  2021-12-12 10:48    Y
# ...        ...         ...   ...  ...               ...               ...  ...
# 182553       5  2020-01-31   9.0  ...  2021-05-27 11:08  2021-05-27 11:08    Y
# 182554       4  2020-01-30   7.0  ...  2021-05-27 11:08  2021-05-27 11:08    Y
# 182555       3  2020-01-30   6.0  ...  2021-05-27 11:08  2021-05-27 11:08    Y
# 182556       2  2020-01-30   5.0  ...  2021-05-27 11:08  2021-05-27 11:08    Y
# 182557       1  2020-01-24   2.0  ...  2021-05-27 11:08  2021-05-27 11:08    Y
#
# [182558 rows x 14 columns]

# %%
plt.figure(figsize=(12, 10))
corona.groupby('확진일')['연번'].count().plot()
plt.show()

# %%
plt.figure(figsize=(12, 10))
corona.groupby('지역')['연번'].count().plot(kind='bar')
plt.show()

# %% [markdown]
# ## 정확한 분석을 위한 데이터 클린징

# %% [markdown]
# 공백이 들어간 경우

# %%
corona.loc[corona['지역'] == '관악구 ']
# Out:
#            연번         확진일  환자번호  ...               등록일               수정일 노출여부
# 1428   181130  2021-12-11   NaN  ...  2021-12-12 10:48  2021-12-12 10:48    Y
# 1464   181094  2021-12-11   NaN  ...  2021-12-12 10:48  2021-12-12 10:48    Y
# 1774   180784  2021-12-11   NaN  ...  2021-12-12 10:48  2021-12-12 10:48    Y
# 12155  170403  2021-12-07   NaN  ...  2021-12-12 10:48  2021-12-12 10:48    Y
#
# [4 rows x 14 columns]

# %% [markdown]
# 공백이 들어가지 않은 경우

# %%
corona.loc[corona['지역'] == '관악구']
# Out:
#             연번         확진일    환자번호  ...               등록일               수정일 노출여부
# 40      182518  2021-12-11     NaN  ...  2021-12-12 10:48  2021-12-12 10:48    Y
# 51      182507  2021-12-11     NaN  ...  2021-12-12 10:48  2021-12-12 10:48    Y
# 70      182488  2021-12-11     NaN  ...  2021-12-12 10:48  2021-12-12 10:48    Y
# 91      182467  2021-12-11     NaN  ...  2021-12-12 10:48  2021-12-12 10:48    Y
# 200     182358  2021-12-11     NaN  ...  2021-12-12 10:48  2021-12-12 10:48    Y
# ...        ...         ...     ...  ...               ...               ...  ...
# 182440     118  2020-03-07  6845.0  ...  2021-05-27 11:08  2021-05-27 11:08    Y
# 182471      87  2020-02-29  3491.0  ...  2021-05-27 11:08  2021-05-27 11:08    Y
# 182484      74  2020-02-28  2466.0  ...  2021-05-27 11:08  2021-05-27 11:08    Y
# 182505      53  2020-02-26  1295.0  ...  2021-05-27 11:08  2021-05-27 11:08    Y
# 182521      37  2020-02-25   935.0  ...  2021-05-27 11:08  2021-05-27 11:08    Y
#
# [9296 rows x 14 columns]

# %% [markdown]
# 공백을 제거하는 함수 `strip()`활용

# %%
corona['지역'].apply(lambda x: x.strip())
# Out:
# 0          기타
# 1         성북구
# 2          중구
# 3          기타
# 4         광진구
#          ...
# 182553    성북구
# 182554    마포구
# 182555    종로구
# 182556    중랑구
# 182557    강서구
# Name: 지역, Length: 182558, dtype: object

# %%
corona['지역'] = corona['지역'].apply(lambda x: x.strip())

# %% [markdown]
# 공백이 들어간 데이터가 제거되었음을 확인합니다.

# %%
corona.loc[corona['지역'] == '관악구 ']
# Out:
# Empty DataFrame
# Columns: [연번, 확진일, 환자번호, 국적, 환자정보, 지역, 여행력, 접촉력, 조치사항, 상태, 이동경로, 등록일, 수정일, 노출여부]
# Index: []

# %% [markdown]
# **구**가 빠진 지역명은 구를 추가합니다.

# %%
plt.figure(figsize=(12, 10))
corona.groupby('지역')['연번'].count().plot(kind='bar')
plt.show()

# %%
target = ['동대문', '서대문', '송파', '영등포']

# %%
corona['지역'].apply(lambda x: x + '구' if x in target else x).value_counts()
# Out:
# 송파구     10932
# 강남구     10358
# 관악구      9300
# 타시도      9057
# 구로구      8932
# 영등포구     8779
# 강서구      8376
# 은평구      7721
# 노원구      7535
# 성북구      7504
# 강동구      7479
# 동대문구     7431
# 동작구      7273
# 중랑구      6815
# 서초구      6750
# 양천구      6341
# 마포구      6202
# 광진구      5826
# 도봉구      5251
# 강북구      5208
# 서대문구     4817
# 금천구      4735
# 성동구      4665
# 기타       4529
# 용산구      4399
# 종로구      3232
# 중구       3111
# Name: 지역, dtype: int64

# %%
corona['지역'] = corona['지역'].apply(lambda x: x + '구' if x in target else x)

# %% [markdown]
# 지역이 깔끔하게 전처리 되었음을 확인합니다.

# %%
plt.figure(figsize=(12, 10))
corona.groupby('지역')['연번'].count().plot(kind='bar')
plt.show()

# %% [markdown]
# 확진자 숫자를 기준으로 오름차순 정렬합니다.

# %%
plt.figure(figsize=(12, 10))
corona.groupby('지역')['연번'].count().sort_values().plot(kind='bar')
plt.show()

# %%
import folium
import requests
import json

# %%
# 서울 행정구역 json raw파일(githubcontent)
r = requests.get('https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json')
c = r.content
seoul_geo = json.loads(c)

# %%
# 위도
latitude = 37.394946
# 경도
longitude = 127.111104

# %%
m = folium.Map(
    location=[37.559819, 126.963895],
    zoom_start=10, 
    tiles='cartodbpositron'
)

folium.GeoJson(
    seoul_geo,
    name='지역구'
).add_to(m)

m.choropleth(geo_data=seoul_geo,
             data=corona.groupby('지역')['연번'].count().sort_values(),
             fill_color='YlOrRd', # 색상 변경도 가능하다
             fill_opacity=0.3,
             line_opacity=0.2,
             key_on='properties.name',
             legend_name=f'코로나 확진자 현황', 
            )
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_0a8d42d74a4e4bf1b1fbf177a989f510%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_0a8d42d74a4e4bf1b1fbf177a989f510%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_0a8d42d74a4e4bf1b1fbf177a989f510%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_0a8d42d74a4e4bf1b1fbf177a989f510%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B37.559819%2C%20126.963895%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_d7fe6aabbbe843acb9c8cd8b029e4150%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//cartodb-basemaps-%7Bs%7D.global.ssl.fastly.net/light_al ...

# %%
corona.head()
# Out:
#        연번         확진일  환자번호  국적  ... 이동경로               등록일               수정일 노출여부
# 0  182558  2021-12-11   NaN NaN  ...  NaN  2021-12-12 10:48  2021-12-12 10:48    Y
# 1  182557  2021-12-11   NaN NaN  ...  NaN  2021-12-12 10:48  2021-12-12 10:48    Y
# 2  182556  2021-12-11   NaN NaN  ...  NaN  2021-12-12 10:48  2021-12-12 10:48    Y
# 3  182555  2021-12-11   NaN NaN  ...  NaN  2021-12-12 10:48  2021-12-12 10:48    Y
# 4  182554  2021-12-11   NaN NaN  ...  NaN  2021-12-12 10:48  2021-12-12 10:48    Y
#
# [5 rows x 14 columns]

# %%
corona_df = corona.groupby('확진일')['연번'].count().reset_index()
corona_df
# Out:
#             확진일    연번
# 0    2020-01-24     1
# 1    2020-01-30     3
# 2    2020-01-31     3
# 3    2020-02-02     1
# 4    2020-02-05     2
# ..          ...   ...
# 651  2021-12-07  2901
# 652  2021-12-08  2790
# 653  2021-12-09  2800
# 654  2021-12-10  2835
# 655  2021-12-11  2528
#
# [656 rows x 2 columns]

# %%
corona_df.columns = ['ds', 'y']
corona_df
# Out:
#              ds     y
# 0    2020-01-24     1
# 1    2020-01-30     3
# 2    2020-01-31     3
# 3    2020-02-02     1
# 4    2020-02-05     2
# ..          ...   ...
# 651  2021-12-07  2901
# 652  2021-12-08  2790
# 653  2021-12-09  2800
# 654  2021-12-10  2835
# 655  2021-12-11  2528
#
# [656 rows x 2 columns]

# %%
from fbprophet import Prophet
from fbprophet.plot import plot_plotly, plot_components_plotly

m = Prophet(changepoint_prior_scale=5.5, yearly_seasonality=False, weekly_seasonality=True, daily_seasonality=False)
m.fit(corona_df)

# %%
future = m.make_future_dataframe(periods=30)
future.tail()
# Out:
#             ds
# 681 2022-01-06
# 682 2022-01-07
# 683 2022-01-08
# 684 2022-01-09
# 685 2022-01-10

# %%
forecast = m.predict(future)
forecast.tail()
# Out:
#             ds        trend  ...  multiplicative_terms_upper         yhat
# 681 2022-01-06  1859.041563  ...                         0.0  1885.766180
# 682 2022-01-07  1869.489891  ...                         0.0  1892.122740
# 683 2022-01-08  1879.938219  ...                         0.0  1876.674276
# 684 2022-01-09  1890.386547  ...                         0.0  1830.736034
# 685 2022-01-10  1900.834875  ...                         0.0  1844.856221
#
# [5 rows x 16 columns]

# %%
fig = m.plot(forecast)

# %%
from fbprophet.plot import add_changepoints_to_plot

fig = m.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), m, forecast)

# %%
# 최근 N일 데이터로 시뮬레이션 결과
N = 200
m = Prophet(changepoint_prior_scale=1.5, yearly_seasonality=False, weekly_seasonality=True, daily_seasonality=False)
forecast = m.fit(corona_df.iloc[-N:]).predict(future.iloc[-N:])
fig = m.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), m, forecast)

# %%
# 최근 N일 데이터로 시뮬레이션 결과
N = 150
m = Prophet(changepoint_prior_scale=1.5, yearly_seasonality=False, weekly_seasonality=True, daily_seasonality=False)
forecast = m.fit(corona_df.iloc[-N:]).predict(future.iloc[-N:])
fig = m.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), m, forecast)

# %%
# 최근 N일 데이터로 시뮬레이션 결과
N = 100
m = Prophet(changepoint_prior_scale=1.5, yearly_seasonality=False, weekly_seasonality=True, daily_seasonality=False)
forecast = m.fit(corona_df.iloc[-N:]).predict(future.iloc[-N:])
fig = m.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), m, forecast)
